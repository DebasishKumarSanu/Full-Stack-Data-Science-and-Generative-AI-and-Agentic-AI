# %% [markdown]
# # VARIABLE DECLARATION
#
# var_name=value

# %%
nit=1030
nit
# Out:
# 1030

# %%
nit1=10
Nit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 nit1=10
# ----> 2 Nit
#
# NameError: name 'Nit' is not defined

# %%
1030=nit
# Out:
#   Cell In[2], line 1
#     1030=nit
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
nit@=23
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 nit@=23
#
# NameError: name 'nit' is not defined

# %%
nit#=12
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 nit#=12
#
# NameError: name 'nit' is not defined

# %%
_nit=30
_nit
# Out:
# 30

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
for=12
# Out:
#   Cell In[9], line 1
#     for=12
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Data Types In python

# %%
int_val=13
type(int_val)
# Out:
# int

# %%
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
int_val
# Out:
# 13

# %%
id(int_val)
# Out:
# 140727063979304

# %%
float_val=34.7
print(float_val)
# Out:
# 34.7

# %%
type(float_val)
# Out:
# float

# %%
id(float_val)
# Out:
# 2863362846960

# %% [markdown]
# # When ever we execute multiple operations, the latest one gets executed but by using print() we can make all the lines of codes executed atonce.

# %%
float_val1=23.45
id(float_val1)
type(float_val1)
float_val1
# Out:
# 23.45

# %%
float_val1=23.45
print(id(float_val1))
print(type(float_val1))
print(float_val1)
# Out:
# 2863353227856
# <class 'float'>
# 23.45

# %%
float_val2=23e2
print(id(float_val2))
print(type(float_val2))
print(float_val2)
# Out:
# 2863362848080
# <class 'float'>
# 2300.0

# %%
float_val3=27.9734E1
print(float_val3)
print(id(float_val3))
print(type(float_val3))
# Out:
# 279.734
# 2863362847888
# <class 'float'>

# %%
bool_val=True
print(bool_val)
print(id(bool_val))
print(type(bool_val))
# Out:
# True
# 140727063067104
# <class 'bool'>

# %%
bool_val0=False
print(bool_val0)
print(type(bool_val0))
print(id(bool_val0))
# Out:
# False
# <class 'bool'>
# 140727063067136

# %%
True+True
# Out:
# 2

# %%
False+False
# Out:
# 0

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True+False
# Out:
# 1

# %%
True+True
# Out:
# 2

# %%
True*False
# Out:
# 0

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
False//True
# Out:
# 0

# %%
False/True
# Out:
# 0.0

# %%
complex_val=27+4j
print(complex_val)
print(type(complex_val))
# Out:
# (27+4j)
# <class 'complex'>

# %%
complex_val.real
# Out:
# 27.0

# %%
complex_val.imag
# Out:
# 4.0

# %%
a=3+4j
b=7+2j
a+b
# Out:
# (10+6j)

# %%
print(a+b)
# Out:
# (10+6j)

# %%
str_obj='Welcomr to the coding world'
print(str_obj)
print(type(str_obj))
print(id(str_obj))
# Out:
# Welcomr to the coding world
# <class 'str'>
# 2863362155712

# %%
str_obj1="python"
print(str_obj1)
# Out:
# python

# %%
str_obj1[3]
# Out:
# 'h'

# %%
str_obj1[-3]
# Out:
# 'h'

# %%
str_obj1[-6]
# Out:
# 'p'

# %%
str_obj1[-7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 str_obj1[-7]
#
# IndexError: string index out of range

# %%
str_obj1[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 str_obj1[6]
#
# IndexError: string index out of range

# %%
str_obj1[0:5]
# Out:
# 'pytho'

# %%
str_obj1[0:6]
# Out:
# 'python'

# %%
str_obj1[0:10]
# Out:
# 'python'

# %%
str_obj1[-1:-6]
# Out:
# ''

# %%
str_obj1[-6:-1]
# Out:
# 'pytho'

# %%
str_obj1[-6:]
# Out:
# 'python'

# %%
str_obj1[:]
# Out:
# 'python'

# %%
str_obj1[::-1]
# Out:
# 'nohtyp'

# %%
str_obj1[::2]
# Out:
# 'pto'

# %% [markdown]
# # Type Casting

# %%
#1.int()

# %%
int(23.4)
# Out:
# 23

# %%
int(23.4e2)
# Out:
# 2340

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(2+3j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 int(2+3j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
int('23.4')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 int('23.4')
#
# ValueError: invalid literal for int() with base 10: '23.4'

# %%
int('True')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 int('True')
#
# ValueError: invalid literal for int() with base 10: 'True'

# %%
int('2+3j')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 int('2+3j')
#
# ValueError: invalid literal for int() with base 10: '2+3j'

# %%
int('Ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 int('Ten')
#
# ValueError: invalid literal for int() with base 10: 'Ten'

# %%
#float()

# %%
float(10)
# Out:
# 10.0

# %%
float(23.4)
# Out:
# 23.4

# %%
float(True)
# Out:
# 1.0

# %%
float(2+3j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 float(2+3j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('10')
# Out:
# 10.0

# %%
float("23.4")
# Out:
# 23.4

# %%
float('True')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 float('True')
#
# ValueError: could not convert string to float: 'True'

# %%
float('2+3j')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 float('2+3j')
#
# ValueError: could not convert string to float: '2+3j'

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %%
#bool()

# %%
bool(10)
# Out:
# True

# %%
bool(-1)
# Out:
# True

# %%
bool(23.54)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(0.5)
# Out:
# True

# %%
bool(2+3j)
# Out:
# True

# %%
bool(0+0j)
# Out:
# False

# %%
bool('10')
# Out:
# True

# %%
bool('23.45')
# Out:
# True

# %%
bool('True')
# Out:
# True

# %%
bool('False')
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
bool('2+3j')
# Out:
# True

# %%
bool('ten   is pure str')
# Out:
# True

# %%
bool("     ")
# Out:
# True

# %%
#complex()

# %%
complex(1)
# Out:
# (1+0j)

# %%
complex(23)
# Out:
# (23+0j)

# %%
complex(23.4)
# Out:
# (23.4+0j)

# %%
complex(0)
# Out:
# 0j

# %%
complex(-23.4)
# Out:
# (-23.4+0j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('23.4')
# Out:
# (23.4+0j)

# %%
complex('True')
